# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data =pd.read_csv('~/Desktop/ets.csv').iloc[:,:-2]

# %%
data.corr(method = 'spearman').style.background_gradient(cmap='YlOrRd').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_f8a30ddc_2af5_11e9_bc6e_2816ade53d31row0_col0 {
#             background-color:  #800026;
#         }    #T_f8a30ddc_2af5_11e9_bc6e_2816ade53d31row0_col1 {
#             background-color:  #fea546;
#         }    #T_f8a30ddc_2af5_11e9_bc6e_2816ade53d31row0_col2 {
#             background-color:  #ffffcc;
#         }    #T_f8a30ddc_2af5_11e9_bc6e_2816ade53d31row0_col3 {
#             background-color:  #ffe48c;
#         }    #T_f8a30ddc_2af5_11e9_bc6e_2816ade53d31row0_col4 {
#             background-color:  #fedb7a;
#         }    #T_f8a30ddc_2af5_11e9_bc6e_2816ade53d31row0_col5 {
#             background-color:  #fea546;
#         }    #T_f8a30ddc_2af5_11e9_bc6e_2816ade53d31row0_col6 {
#             background-color:  #fecc68;
#         }    #T_f8a30ddc_2af5_11e9_bc6e_2816ade53d31row0_col7 {
#             background-color:  #fed977;
#         }    #T_f8a30ddc_2af5_11e9_bc6e_2816ade53d31row0_col8 {
#             background-color:  #fd8e3c;
# ...
